# %%
# %load_ext autoreload
# %autoreload 2

from melodies_monet import driver
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
an = driver.analysis()

# %%
an.control = '../yaml/control_tempo_l2_hcho.yaml'
an.read_control()

# %%
an.open_models()
# Out:
# wrfchem
# /glade/campaign/acom/acom-da/shawnh/AQ_WATCH/20240905/wrf/wrfout_hourly_d02_2024-09-0[5-7]*
# **** Reading WRF-Chem model output...

# %%
an.open_obs()
# Out:
# Reading TEMPO L2
# /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_2024090[5-6]*_S0*
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240905T000407Z_S016G02.nc
# /glade/u/home/plichtig/melodies-monet/monetio/monetio/sat/_tempo_l2_no2_mm.py:67: UserWarning: Calculating pressure in TEMPO data requires surface_pressure. Adding surface_pressure to output variables
#   warnings.warn(
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240905T001044Z_S016G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240905T001722Z_S016G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240905T002359Z_S016G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240905T003036Z_S016G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_HCHO_V03/TEMPO_HCHO_L2_V03_20240905T003732Z_S017G01.nc
# ...

# %%
an.pair_data()
# Out:
# 1, in pair data
# /glade/u/home/plichtig/melodies-monet/MELODIES-MONET/melodies_monet/util/sat_l2_swath_utility_tempo.py:566: UserWarning: 2024-09-05T00:04:07Z granule domain has no overlap with model. Discarding.
#   warnings.warn(f"{ref_time} granule domain has no overlap with model. Discarding.")
# Regridding 2024-09-05T00:10:44Z and applying AMF and weights
# Regridding 2024-09-05T00:17:22Z and applying AMF and weights
# Regridding 2024-09-05T00:23:59Z and applying AMF and weights
# /glade/u/home/plichtig/melodies-monet/MELODIES-MONET/melodies_monet/util/sat_l2_swath_utility_tempo.py:566: UserWarning: 2024-09-05T00:30:36Z granule domain has no overlap with model. Discarding.
#   warnings.warn(f"{ref_time} granule domain has no overlap with model. Discarding.")
# /glade/u/home/plichtig/melodies-monet/MELODIES-MONET/melodies_monet/util/sat_l2_swath_utility_tempo.py:566: UserWarning: 2024-09-05T00:37:32Z granule domain has no overlap with model. Discarding.
# ...

# %%
an.paired['tempo_l2_hcho_wrfchem_v4.2'].obj
# Out:
# <xarray.Dataset> Size: 13MB
# Dimensions:          (time: 29, y: 153, x: 174)
# Coordinates:
#   * time             (time) datetime64[ns] 232B 2024-09-05T00:10:44 ... 2024-...
#     longitude        (y, x) float32 106kB -109.4 -109.3 -109.3 ... -102.0 -101.9
#     latitude         (y, x) float32 106kB 36.09 36.09 36.1 ... 42.37 42.37 42.38
# Dimensions without coordinates: y, x
# Data variables:
#     hcho             (time, y, x) float64 6MB nan nan nan nan ... nan nan nan
#     vertical_column  (time, y, x) float64 6MB 6.816e+14 2.426e+15 ... 2.369e+15
#     end_time         (time) datetime64[ns] 232B 2024-09-05T00:30:51.802469 .....

# %%
an.read_control()
an.plotting()
plt.show()
# Out:
# ...
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 1.2, 'markersize': 6.0, 'label': 'vertical_column', 'fontsize': 11.200000000000001}
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 41 57
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 110 9
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 131 65536
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 41 9
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 62 8192
# ...
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 1.2, 'markersize': 6.0, 'label': 'vertical_column', 'fontsize': 11.200000000000001}
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 41 57
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 110 9
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 131 65536
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 41 9
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 62 8192
# ...

# %%
an.read_control()
an.save_analysis()
# Out:
# Writing: ./tempo_l2_hcho_wrfchem_v4.2.nc4

# %%
an.read_analysis()
# Out:
# Reading: ./tempo_l2_hcho_wrfchem_v4.2.nc4

# %%
an.plotting()
plt.show()
# Out:
# ...
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 1.2, 'markersize': 6.0, 'label': 'vertical_column', 'fontsize': 11.200000000000001}
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 41 57
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 110 9
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 131 65536
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 41 9
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 62 8192
# ...
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 1.2, 'markersize': 6.0, 'label': 'vertical_column', 'fontsize': 11.200000000000001}
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 41 57
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 110 9
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 131 65536
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'pHYs' 41 9
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 62 8192
# ...
