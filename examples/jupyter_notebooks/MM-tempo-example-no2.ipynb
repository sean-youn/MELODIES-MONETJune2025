# %%
# %load_ext autoreload
# %autoreload 2

from melodies_monet import driver

# %%
an = driver.analysis()

# %%
an.control = '../yaml/control_tempo_l2_no2.yaml'
an.read_control()

# %%
an.open_models()
ds = an.models['wrfchem_v4.2'].obj
# Out:
# wrfchem
# /glade/campaign/acom/acom-da/shawnh/AQ_WATCH/20240905/wrf/wrfout_hourly_d02_2024-09-0[5-7]*
# **** Reading WRF-Chem model output...

# %%
an.open_obs()
ds_obs = an.obs['tempo_l2_no2'].obj
# Out:
# Reading TEMPO L2
# /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906*_S0*
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T000020Z_S015G03.nc
# /glade/u/home/plichtig/melodies-monet/monetio/monetio/sat/_tempo_l2_no2_mm.py:66: UserWarning: Calculating pressure in TEMPO data requires surface_pressure. Adding surface_pressure to output variables
#   warnings.warn(
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T000658Z_S015G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T001335Z_S015G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T002012Z_S015G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T114628Z_S002G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T115308Z_S002G02.nc
# ...

# %%
an.open_obs()
ds_obs = an.obs['tempo_l2_no2'].obj
an.models['wrfchem_v4.2'].obj = ds
an.pair_data()
an.save_analysis()
# Out:
# Reading TEMPO L2
# /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906*_S0*
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T000020Z_S015G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T000658Z_S015G04.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T001335Z_S015G05.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T002012Z_S015G06.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T114628Z_S002G01.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T115308Z_S002G02.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T115945Z_S002G03.nc
# reading /glade/campaign/acom/acom-da/sma/TEMPO_NO2_V03/TEMPO_NO2_L2_V03_20240906T120623Z_S002G04.nc
# ...

# %%
an.paired['tempo_l2_no2_wrfchem_v4.2'].obj
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:                      (time: 14, y: 153, x: 174)
# Coordinates:
#   * time                         (time) datetime64[ns] 112B 2024-09-06T00:00:...
#     longitude                    (y, x) float32 106kB -109.4 -109.3 ... -101.9
#     latitude                     (y, x) float32 106kB 36.09 36.09 ... 42.38
# Dimensions without coordinates: y, x
# Data variables:
#     no2                          (time, y, x) float64 3MB nan nan ... nan nan
#     vertical_column_troposphere  (time, y, x) float64 3MB 4.438e+14 ... 9.748...
#     end_time                     (time) datetime64[ns] 112B 2024-09-06T00:20:...
# Attributes:
#     title:
#     format:        NetCDF-4
#     date_created:  2024-10-15
#     dict_json:     {\n    "type": "sat_swath_clm",\n    "radius_of_influence"...
#     group_name:    tempo_l2_no2_wrfchem_v4.2

# %%
an.read_control()
an.plotting()
# Out:
# ...
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 1.2, 'markersize': 6.0, 'label': 'vertical_column_troposphere', 'fontsize': 11.200000000000001}
# ...
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 1.2, 'markersize': 6.0, 'label': 'vertical_column_troposphere', 'fontsize': 11.200000000000001}
# ...
# {'color': 'k', 'linestyle': '-', 'marker': '*', 'linewidth': 1.2, 'markersize': 6.0, 'label': 'vertical_column_troposphere', 'fontsize': 11.200000000000001}
# -2994158302787589.5 2994158302787589.5
# -2994158302787589.5 2994158302787589.5
# 0 1e+16
# 0 1e+16
# 0 1e+16
# 0 1e+16
# ...
# Base standard deviation:  9.48e+14
# Reference std: 1

# %%
import matplotlib.pyplot as plt
plt.show()

# %%
an.read_control()
an.stats()
